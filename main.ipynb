# %%
import os
from zipfile import ZipFile
import pandas as pd
import requests

# %%
base_path = os.getcwd()
download_path = os.path.join(base_path, 'cvm_data')
base_url = 'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/'

file_paths = []
for year in range(2010,2022):
    file_name = f'dfp_cia_aberta_{year}.zip'

    response = requests.get(f'{base_url}{file_name}')

    file_path = os.path.join(download_path, file_name)

    with open(file_path, 'wb') as file:
        file.write(response.content)
    
    file_paths.append(file_path)

# %%
financial_statements = []
for file_path in file_paths:
    zipped_file = ZipFile(file_path)

    for financial_statement in zipped_file.namelist():
        with zipped_file.open(financial_statement, 'r') as unzipped_file:
            financial_statement = pd.read_csv(unzipped_file, delimiter=';', encoding='latin-1')
            financial_statements.append(financial_statement)

untreated_df = pd.concat(financial_statements)

untreated_df
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO                 DENOM_CIA  \
# 0      00.000.000/0001-91  2010-12-31       1           BCO BRASIL S.A.
# 1      00.000.000/0001-91  2010-12-31       2           BCO BRASIL S.A.
# 2      00.000.000/0001-91  2010-12-31       3           BCO BRASIL S.A.
# 3      00.000.208/0001-00  2010-12-31       1  BRB BCO DE BRASILIA S.A.
# 4      00.000.208/0001-00  2010-12-31       2  BRB BCO DE BRASILIA S.A.
# ...                   ...         ...     ...                       ...
# 62931  97.837.181/0001-47  2021-12-31       1                DEXCO S.A.
# 62932  97.837.181/0001-47  2021-12-31       1                DEXCO S.A.
# 62933  97.837.181/0001-47  2021-12-31       1                DEXCO S.A.
# 62934  97.837.181/0001-47  2021-12-31       1                DEXCO S.A.
# 62935  97.837.181/0001-47  2021-12-31       1                DEXCO S.A.
#
#        CD_CVM CATEG_DOC  ID_DOC    DT_RECEB  \
# 0        1023       DFP  4822.0  2011-02-17
# 1        1023       DFP  4823.0  2011-02-17
# 2        1023       DFP  6945.0  2011-04-30
# 3       14206       DFP  5436.0  2011-03-22
# 4       14206       DFP  6775.0  2011-04-29
# ...       ...       ...     ...         ...
# 62931   21091       NaN     NaN         NaN
# 62932   21091       NaN     NaN         NaN
# 62933   21091       NaN     NaN         NaN
# 62934   21091       NaN     NaN         NaN
# 62935   21091       NaN     NaN         NaN
#
#                                                 LINK_DOC  \
# 0      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 1      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 2      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 3      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# 4      http://www.rad.cvm.gov.br/ENETCONSULTA/frmDown...
# ...                                                  ...
# 62931                                                NaN
# 62932                                                NaN
# 62933                                                NaN
# 62934                                                NaN
# 62935                                                NaN
#
#                                               GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0                                                   NaN   NaN          NaN
# 1                                                   NaN   NaN          NaN
# 2                                                   NaN   NaN          NaN
# 3                                                   NaN   NaN          NaN
# 4                                                   NaN   NaN          NaN
# ...                                                 ...   ...          ...
# 62931  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 62932  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 62933  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 62934  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
# 62935  DF Individual - Demonstração de Valor Adicionado  REAL          MIL
#
#       ORDEM_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0             NaN          NaN         NaN
# 1             NaN          NaN         NaN
# 2             NaN          NaN         NaN
# 3             NaN          NaN         NaN
# 4             NaN          NaN         NaN
# ...           ...          ...         ...
# 62931      ÚLTIMO   2021-12-31  7.08.04.02
# 62932   PENÚLTIMO   2020-12-31  7.08.04.03
# 62933      ÚLTIMO   2021-12-31  7.08.04.03
# 62934   PENÚLTIMO   2020-12-31     7.08.05
# 62935      ÚLTIMO   2021-12-31     7.08.05
#
#                                    DS_CONTA  VL_CONTA ST_CONTA_FIXA  \
# 0                                       NaN       NaN           NaN
# 1                                       NaN       NaN           NaN
# 2                                       NaN       NaN           NaN
# 3                                       NaN       NaN           NaN
# 4                                       NaN       NaN           NaN
# ...                                     ...       ...           ...
# 62931                            Dividendos       0.0             S
# 62932  Lucros Retidos / Prejuízo do Período  236712.0             S
# 62933  Lucros Retidos / Prejuízo do Período  847006.0             S
# 62934                                Outros       0.0             S
# 62935                                Outros       0.0             S
#
#       DT_INI_EXERC COLUNA_DF
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 62931   2021-01-01       NaN
# 62932   2020-01-01       NaN
# 62933   2021-01-01       NaN
# 62934   2020-01-01       NaN
# 62935   2021-01-01       NaN
#
# [12083560 rows x 20 columns]
